# %% [markdown]
# # Arithmetic Script
#
# ### 1. Addition

# %%
# Defining Variables
x = 2
y = 3

addition = x + y

print('Sum: {}'.format(addition))
# Out:
# Sum: 5

# %% [markdown]
# ### 2. Subtraction

# %%
subtraction = y - x

print('Difference: {}'.format(subtraction))
# Out:
# Difference: 1
