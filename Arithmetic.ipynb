# %% [markdown]
# # Arithmetic Script
#
# ### 1. Addition

# %%
# Defining Variables
x = 2
y = 3

addition = x + y

print('Sum: {}'.format(addition))
# Out:
# Sum: 5

# %% [markdown]
# ### 2. Subtraction

# %%
subtraction = y - x

print('Difference: {}'.format(subtraction))
# Out:
# Difference: 1

# %% [markdown]
# ### 3. Multiplication

# %%
multiplication = x * y

print('Product: {}'.format(multiplication))
# Out:
# Product: 6

# %% [markdown]
# ### 4. Division

# %%
division = x / y

print('Quotient: {}'.format(division))
# Out:
# Quotient: 0.6666666666666666

# %% [markdown]
# ---
#
# ### 5. Formula

# %%
formula_01 = (x + y) + 1

print('Formula 01 Result: {}'.format(formula_01))
# Out:
# Formula 01 Result: 6

# %% [markdown]
# ### 5. Formula (COPY!!!)

# %%
formula_01 = (x + y) + 1

print('Formula 01 Result: {}'.format(formula_01))
# Out:
# Formula 01 Result: 6
